# %%
# !nvidia-smi
# Out:
# Mon Apr  8 17:46:17 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# #Para borrar archivos
# # Clear output folder
# import os

# def remove_folder_contents(folder):
#     for the_file in os.listdir(folder):
#         file_path = os.path.join(folder, the_file)
#         try:
#             if os.path.isfile(file_path):
#                 os.unlink(file_path)
#             elif os.path.isdir(file_path):
#                 remove_folder_contents(file_path)
#                 os.rmdir(file_path)
#         except Exception as e:
#             print(e)

# folder_path = '/kaggle/working'
# remove_folder_contents(folder_path)
# os.rmdir(folder_path)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5563.1/8062.4 GB disk)

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 23909, done.
# remote: Counting objects: 100% (954/954), done.
# remote: Compressing objects: 100% (672/672), done.
# remote: Total 23909 (delta 609), reused 500 (delta 282), pack-reused 22955
# Receiving objects: 100% (23909/23909), 14.34 MiB | 23.16 MiB/s, done.
# Resolving deltas: 100% (16702/16702), done.

# %%
# # Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets




# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6kshFcsZENZYGREqxSaw")
project = rf.workspace("cvproject-d8hm5").project("cv-project-4-c")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# /kaggle/working/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 29.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
# ...

# %%
# %cd /kaggle/working/ultralytics
# !wget https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8x-seg.pt

# %%
import yaml

data = {
    'names': ['COW', 'Cattle', 'horse', 'pig', 'sheep', 'undefined'],
    'nc': 6,
    'test': '/kaggle/working/datasets/CV-PROJECT-4-C-3/test/images',
    'train': '/kaggle/working/datasets/CV-PROJECT-4-C-3/train/images',
    'val': '/kaggle/working/datasets/CV-PROJECT-4-C-3/valid/images'
}

with open('data.yml', 'w') as file:
    yaml.dump(data, file, default_flow_style=False)

# %%
# %%writefile /kaggle/working/data.yml
# names:
#   - 'COW'
#   - 'Cattle'
#   - 'horse'
#   - 'pig'
#   - 'sheep'
#   - 'undefined'
# nc: 6
# test: '/kaggle/working/datasets/CV-PROJECT-4-C-3/test/images'
# train: '/kaggle/working/datasets/CV-PROJECT-4-C-3/train/images'
# val: '/kaggle/working/datasets/CV-PROJECT-4-C-3/valid/images'
# Out:
# Writing /kaggle/working/data.yml

# %% [markdown]
# ## Custom Training

# %%
# !pip install ultralytics

# %%
cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolov8x-seg.pt data=/kaggle/input/12313131/data.yml epochs=10 imgsz=640

# !yolo task=segment mode=train model=yolov8x-seg.pt data=/kaggle/input/12313131/data.yml epochs=100 imgsz=640  
# !yolo task=segment mode=train model=yolov8n-seg.pt data=/kaggle/working/data.yml epochs=100 imgsz=640 batch=32 device=0,1
# !yolo task=segment mode=train model=yolov8x-seg.pt data=/kaggle/working/data.yml epochs=100 imgsz=640 batch=32 device=0,1
# Out:
# ...
# 100%|█████████████████████████████████████████| 137M/137M [00:00<00:00, 266MB/s]
# New https://pypi.org/project/ultralytics/8.1.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                        CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
# cd /kaggle/working/ultralytics/runs/segment/train

# %%
# import os
# HOME = os.getcwd()
# print(HOME)

# %%
# !ls /kaggle/working/runs/segment/train/
# Out:
# BoxF1_curve.png					   results.png
# BoxPR_curve.png					   train_batch0.jpg
# BoxP_curve.png					   train_batch1.jpg
# BoxR_curve.png					   train_batch13770.jpg
# MaskF1_curve.png				   train_batch13771.jpg
# MaskPR_curve.png				   train_batch13772.jpg
# MaskP_curve.png					   train_batch2.jpg
# MaskR_curve.png					   val_batch0_labels.jpg
# args.yaml					   val_batch0_pred.jpg
# confusion_matrix.png				   val_batch1_labels.jpg
# confusion_matrix_normalized.png			   val_batch1_pred.jpg
# events.out.tfevents.1712598488.7c64c301815a.107.0  val_batch2_labels.jpg
# labels.jpg					   val_batch2_pred.jpg
# labels_correlogram.jpg				   weights
# results.csv

# %%
# # %cd {HOME}
# Image(filename=f'confusion_matrix.png', width=600)

# %%
# # %cd {HOME}
# Image(filename=f'results.png', width=600)

# %%
# # %cd {HOME}
# Image(filename=f'val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=segment mode=val model=/kaggle/working/runs/segment/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71726434 parameters, 0 gradients, 343.7 GFLOPs
# val: Scanning /kaggle/working/datasets/CV-PROJECT-4-C-3/valid/labels.cache... 11
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1195       4012       0.77      0.738      0.773      0.729       0.77      0.737      0.774      0.699
#                    COW       1195        663      0.985      0.979      0.991      0.983      0.985      0.979      0.994      0.967
#                 Cattle       1195        110      0.993      0.936      0.986      0.955      0.993      0.936      0.986      0.949
#                  horse       1195       2141      0.988      0.985      0.994      0.939      0.986      0.982      0.993      0.878
# ...

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=/kaggle/working/runs/segment/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=true
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71726434 parameters, 0 gradients, 343.7 GFLOPs
#
# image 1/508 /kaggle/working/datasets/CV-PROJECT-4-C-3/test/images/-OWS_mp4-123_jpg.rf.7d912da73c474187ace2889c5b1e4c31.jpg: 640x640 6 COWs, 108.3ms
# image 2/508 /kaggle/working/datasets/CV-PROJECT-4-C-3/test/images/-OWS_mp4-140_jpg.rf.f6729aea4b80b30ae73e01a59f8352ff.jpg: 640x640 1 COW, 65.2ms
# image 3/508 /kaggle/working/datasets/CV-PROJECT-4-C-3/test/images/-OWS_mp4-156_jpg.rf.5fcb6562a1c42de6f4451c7ed5d4746f.jpg: 640x640 3 COWs, 69.8ms
# image 4/508 /kaggle/working/datasets/CV-PROJECT-4-C-3/test/images/-OWS_mp4-161_jpg.rf.5e7e38eb51be7d61447f9553bd577d08.jpg: 640x640 1 COW, 69.2ms
# image 5/508 /kaggle/working/datasets/CV-PROJECT-4-C-3/test/images/-OWS_mp4-163_jpg.rf.457066be9740b5c12ab2d218fedeb49e.jpg: 640x640 1 COW, 68.7ms
# ...

# %%
# import glob
# from IPython.display import Image, display

# for image_path in glob.glob(f'{/kaggle/working/ultralytics/runs/segment/predict2/*.jpg')[:3]:
#       display(Image(filename=image_path, height=600))
#       print("\n")

# %%
# dataset

# %%
# project.version(dataset.version).deploy(model_type="yolov8-seg", model_path=f"{HOME}/runs/segment/train3/")
