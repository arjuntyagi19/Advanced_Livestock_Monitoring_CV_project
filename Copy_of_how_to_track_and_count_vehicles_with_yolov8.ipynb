# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Apr 28 13:54:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download video

# %%
# %cd {HOME}
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O vehicle-counting.mp4 && rm -rf /tmp/cookies.txt
# Out:
# /content
# --2024-04-28 13:54:59--  https://docs.google.com/uc?export=download&confirm=&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-
# Resolving docs.google.com (docs.google.com)... 209.85.147.138, 209.85.147.139, 209.85.147.100, ...
# Connecting to docs.google.com (docs.google.com)|209.85.147.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-&export=download [following]
# --2024-04-28 13:54:59--  https://drive.usercontent.google.com/download?id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.121.132, 2607:f8b0:4001:c19::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.121.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35345757 (34M) [video/mp4]
# Saving to: ‘vehicle-counting.mp4’
#
# vehicle-counting.mp 100%[===================>]  33.71M  --.-KB/s    in 0.1s
#
# 2024-04-28 13:55:00 (237 MB/s) - ‘vehicle-counting.mp4’ saved [35345757/35345757]

# %%
SOURCE_VIDEO_PATH = f"{HOME}/vehicle-counting.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %% [markdown]
# ## Install ByteTrack
#
# [ByteTrack](https://github.com/ifzhang/ByteTrack) is great tracker but a bit poorly packaged. We need to jump through some fire hoops to make it work in tandem with [YOLOv8](https://github.com/ultralytics/ultralytics).

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "yolov8n-seg.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-seg.pt to 'yolov8n-seg.pt'...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 83.5MB/s]
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs

# %% [markdown]
# ## Predict and annotate single frame

# %%
# !ls
# Out:
# 85146-587630751_small.mp4  deploy      README.md	 tools	     yolov8x-seg.pt
# assets			   Dockerfile  requirements.txt  tutorials   yolox
# build			   exps        setup.cfg	 videos      yolox.egg-info
# datasets		   LICENSE     setup.py		 yolov8x.pt

# %%
# !wget https://cdn.pixabay.com/video/2016/01/18/1949-152220012.mp4?download
# Out:
# --2024-04-28 14:21:15--  https://cdn.pixabay.com/video/2016/01/18/1949-152220012.mp4?download
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 172.64.147.160, 104.18.40.96, 2606:4700:4400::ac40:93a0, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|172.64.147.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44378449 (42M) [video/mp4]
# Saving to: ‘1949-152220012.mp4?download’
#
# 1949-152220012.mp4? 100%[===================>]  42.32M  71.6MB/s    in 0.6s
#
# 2024-04-28 14:21:16 (71.6 MB/s) - ‘1949-152220012.mp4?download’ saved [44378449/44378449]

# %%
SOURCE_VIDEO_PATH = "/content/ByteTrack/1949-152220012.mp4?download"

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [18, 19, 17, 7]

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 384x640 28 cows, 126.2ms
# Speed: 2.7ms preprocess, 126.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# # settings
# LINE_START = Point(1214, 1500)
# LINE_END = Point(3840-50, 1500)
# [190, 1074],[202, 10]

LINE_START = Point(190, 1074)
LINE_END = Point(202, 10)


TARGET_VIDEO_PATH = f"{HOME}/countingresult.mp4"

# %%
# SOURCE_VIDEO_PATH = r"/content/ByteTrack/85146-587630751_small.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1920, height=1080, fps=50, total_frames=1848)

# %%
from tqdm.notebook import tqdm

np.float = float
np.int = int   #module 'numpy' has no attribute 'int'
np.object = object    #module 'numpy' has no attribute 'object'
np.bool = bool    #module 'numpy' has no attribute 'bool'

# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/1848 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 24 cows, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 13.2ms
# Speed: 3.1ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.9ms
# Speed: 3.8ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.4ms
# Speed: 4.7ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.6ms
# Speed: 3.5ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.8ms
# Speed: 4.4ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 14.3ms
# Speed: 3.6ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 12.3ms
# Speed: 3.1ms preprocess, 12.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 12.7ms
# Speed: 3.9ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 cows, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 9.1ms
# Speed: 4.9ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 12.2ms
# Speed: 2.6ms preprocess, 12.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 13.4ms
# Speed: 3.4ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.7ms
# Speed: 2.9ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.2ms
# Speed: 3.3ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.1ms
# Speed: 3.1ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.4ms
# Speed: 2.8ms preprocess, 12.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 42.6ms
# Speed: 2.9ms preprocess, 42.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 21.7ms
# Speed: 2.9ms preprocess, 21.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 34.1ms
# Speed: 2.9ms preprocess, 34.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.6ms
# Speed: 2.9ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 19.1ms
# Speed: 3.2ms preprocess, 19.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.7ms
# Speed: 2.9ms preprocess, 11.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 16.6ms
# Speed: 3.2ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 15.8ms
# Speed: 3.0ms preprocess, 15.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 10.3ms
# Speed: 5.0ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 14.2ms
# Speed: 2.8ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 16.8ms
# Speed: 3.2ms preprocess, 16.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 12.8ms
# Speed: 6.9ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 27.4ms
# Speed: 3.3ms preprocess, 27.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 16.2ms
# Speed: 3.2ms preprocess, 16.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 19.1ms
# Speed: 2.9ms preprocess, 19.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 25.1ms
# Speed: 3.2ms preprocess, 25.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 13.8ms
# Speed: 3.1ms preprocess, 13.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 15.7ms
# Speed: 4.8ms preprocess, 15.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 15.8ms
# Speed: 3.6ms preprocess, 15.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 20.0ms
# Speed: 2.9ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 17.8ms
# Speed: 8.7ms preprocess, 17.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.2ms
# Speed: 2.7ms preprocess, 13.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.2ms
# Speed: 2.8ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 2 elephants, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 2 elephants, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 2 elephants, 18.3ms
# Speed: 2.8ms preprocess, 18.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 2 elephants, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 2 elephants, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 12.3ms
# Speed: 3.1ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 16.3ms
# Speed: 3.6ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 1 elephant, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 16.3ms
# Speed: 4.1ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 14.8ms
# Speed: 2.8ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 9.4ms
# Speed: 12.6ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.5ms
# Speed: 3.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 11.1ms
# Speed: 5.7ms preprocess, 11.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 12.6ms
# Speed: 9.9ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.8ms
# Speed: 4.7ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.4ms
# Speed: 3.1ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 10.1ms
# Speed: 8.9ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 15.3ms
# Speed: 3.2ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.0ms
# Speed: 4.2ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.1ms
# Speed: 2.9ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.5ms
# Speed: 3.4ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 12.2ms
# Speed: 3.1ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.4ms
# Speed: 2.8ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 14.8ms
# Speed: 4.5ms preprocess, 14.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 28 cows, 13.4ms
# Speed: 9.2ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 25 cows, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.1ms
# Speed: 2.9ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 30 cows, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 15.5ms
# Speed: 9.1ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 16.7ms
# Speed: 2.9ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 11.4ms
# Speed: 10.4ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 21.4ms
# Speed: 7.4ms preprocess, 21.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 10.1ms
# Speed: 8.3ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 13.8ms
# Speed: 3.6ms preprocess, 13.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 16.0ms
# Speed: 4.2ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.8ms
# Speed: 2.7ms preprocess, 13.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.3ms
# Speed: 10.3ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 13.7ms
# Speed: 3.3ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 10.3ms
# Speed: 3.1ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 13.1ms
# Speed: 3.8ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 23 cows, 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 23 cows, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 23 cows, 12.3ms
# Speed: 4.9ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 24 cows, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.0ms
# Speed: 3.1ms preprocess, 11.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 15.4ms
# Speed: 4.1ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 12.5ms
# Speed: 4.3ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 12.6ms
# Speed: 3.3ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 16.4ms
# Speed: 3.6ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.6ms
# Speed: 5.3ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.5ms
# Speed: 6.4ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 1 elephant, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 2 elephants, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 2 elephants, 13.4ms
# Speed: 3.3ms preprocess, 13.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 13.9ms
# Speed: 8.1ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.9ms
# Speed: 3.4ms preprocess, 12.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 10.3ms
# Speed: 4.5ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 11.3ms
# Speed: 3.1ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.3ms
# Speed: 2.9ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 19.2ms
# Speed: 4.8ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.4ms
# Speed: 3.3ms preprocess, 12.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.3ms
# Speed: 2.9ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.6ms
# Speed: 2.8ms preprocess, 12.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 12.7ms
# Speed: 2.9ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 13.6ms
# Speed: 2.8ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 13.8ms
# Speed: 2.9ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 12.6ms
# Speed: 2.8ms preprocess, 12.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 24 cows, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 22 cows, 11.3ms
# Speed: 3.1ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 23 cows, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 22 cows, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 25 cows, 12.8ms
# Speed: 3.3ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 24 cows, 10.0ms
# Speed: 3.2ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 25 cows, 11.8ms
# Speed: 3.1ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.4ms
# Speed: 3.2ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.2ms
# Speed: 3.1ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 23 cows, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 21 cows, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 9.4ms
# Speed: 3.3ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.6ms
# Speed: 4.4ms preprocess, 12.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 13.3ms
# Speed: 3.6ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.2ms
# Speed: 3.1ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.1ms
# Speed: 3.9ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 13.6ms
# Speed: 2.9ms preprocess, 13.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 16.1ms
# Speed: 4.2ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 33.3ms
# Speed: 4.2ms preprocess, 33.3ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 18.5ms
# Speed: 9.4ms preprocess, 18.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 18.1ms
# Speed: 4.4ms preprocess, 18.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 16.4ms
# Speed: 3.2ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.3ms
# Speed: 3.6ms preprocess, 12.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 12.9ms
# Speed: 3.1ms preprocess, 12.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 14.2ms
# Speed: 5.1ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 12.0ms
# Speed: 4.7ms preprocess, 12.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 15.3ms
# Speed: 3.2ms preprocess, 15.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 cows, 10.9ms
# Speed: 5.7ms preprocess, 10.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 10.9ms
# Speed: 3.4ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 19.2ms
# Speed: 6.9ms preprocess, 19.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 17.7ms
# Speed: 3.0ms preprocess, 17.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 15.5ms
# Speed: 2.9ms preprocess, 15.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 cows, 20.9ms
# Speed: 3.2ms preprocess, 20.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 20.2ms
# Speed: 4.0ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 horses, 21 cows, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 horses, 23 cows, 11.5ms
# Speed: 10.0ms preprocess, 11.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 horses, 25 cows, 13.6ms
# Speed: 3.5ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 27 cows, 16.6ms
# Speed: 3.1ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 cows, 27.5ms
# Speed: 3.2ms preprocess, 27.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 23.8ms
# Speed: 4.2ms preprocess, 23.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 20.4ms
# Speed: 4.5ms preprocess, 20.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 15.2ms
# Speed: 3.2ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 horses, 16 cows, 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 22 cows, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 25 cows, 14.5ms
# Speed: 3.2ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 26 cows, 9.1ms
# Speed: 5.0ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 horses, 20 cows, 12.0ms
# Speed: 4.5ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 14.5ms
# Speed: 4.7ms preprocess, 14.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 11.9ms
# Speed: 3.2ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 21 cows, 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 24 cows, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 18.2ms
# Speed: 3.4ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 15.3ms
# Speed: 3.5ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 cows, 10.6ms
# Speed: 6.4ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 11.5ms
# Speed: 6.8ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.1ms
# Speed: 3.1ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.7ms
# Speed: 3.2ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 13.4ms
# Speed: 2.7ms preprocess, 13.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.4ms
# Speed: 4.1ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 12.0ms
# Speed: 4.3ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 13.6ms
# Speed: 3.4ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 12.4ms
# Speed: 3.2ms preprocess, 12.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 14.7ms
# Speed: 4.1ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 11.4ms
# Speed: 3.2ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.5ms
# Speed: 11.5ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 14.2ms
# Speed: 3.0ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 cows, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 13.4ms
# Speed: 3.7ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 13.2ms
# Speed: 4.4ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 12.8ms
# Speed: 5.1ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 13.4ms
# Speed: 2.8ms preprocess, 13.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 13.6ms
# Speed: 2.9ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.9ms
# Speed: 3.6ms preprocess, 12.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.4ms
# Speed: 3.4ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 12.4ms
# Speed: 3.3ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.2ms
# Speed: 3.1ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 14.0ms
# Speed: 3.3ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.1ms
# Speed: 10.4ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 cows, 10.7ms
# Speed: 2.8ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 9.2ms
# Speed: 2.9ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.7ms
# Speed: 4.6ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.0ms
# Speed: 7.5ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 14.4ms
# Speed: 2.8ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 13.9ms
# Speed: 2.9ms preprocess, 13.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.8ms
# Speed: 3.3ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.7ms
# Speed: 3.7ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 14.5ms
# Speed: 3.4ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 13.2ms
# Speed: 2.9ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 12.6ms
# Speed: 5.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 cows, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 cows, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 14.2ms
# Speed: 3.0ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 16.0ms
# Speed: 3.1ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.6ms
# Speed: 5.1ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 10.7ms
# Speed: 5.2ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 13.7ms
# Speed: 5.3ms preprocess, 13.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 12.2ms
# Speed: 4.0ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 9.3ms
# Speed: 5.2ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.2ms
# Speed: 3.2ms preprocess, 12.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 cows, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.4ms
# Speed: 3.7ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 9.7ms
# Speed: 3.5ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 18.3ms
# Speed: 3.6ms preprocess, 18.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 13.9ms
# Speed: 3.3ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 8.9ms
# Speed: 11.0ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 11.7ms
# Speed: 3.8ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 14.6ms
# Speed: 3.5ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 cows, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.9ms
# Speed: 3.0ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cows, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cows, 11.3ms
# Speed: 3.2ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cows, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
# Speed: 2.9ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 15.6ms
# Speed: 3.9ms preprocess, 15.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 10.3ms
# Speed: 6.7ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 21.2ms
# Speed: 5.0ms preprocess, 21.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 15.4ms
# Speed: 2.8ms preprocess, 15.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 17.4ms
# Speed: 2.9ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cows, 10.8ms
# Speed: 6.3ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 16.5ms
# Speed: 5.4ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cows, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 14.8ms
# Speed: 3.2ms preprocess, 14.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 12.8ms
# Speed: 3.6ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 11.8ms
# Speed: 4.5ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 16.3ms
# Speed: 4.8ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 15.2ms
# Speed: 2.9ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 11.6ms
# Speed: 8.3ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 13.0ms
# Speed: 2.9ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 11.9ms
# Speed: 3.2ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 16.5ms
# Speed: 5.3ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cows, 16.4ms
# Speed: 2.8ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 19.0ms
# Speed: 2.9ms preprocess, 19.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.0ms
# Speed: 3.1ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 20.5ms
# Speed: 2.9ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 12.7ms
# Speed: 3.0ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 23.0ms
# Speed: 2.9ms preprocess, 23.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cows, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 15.2ms
# Speed: 3.3ms preprocess, 15.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 15.8ms
# Speed: 5.4ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 12 cows, 14.2ms
# Speed: 3.1ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 13.6ms
# Speed: 3.1ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 9.9ms
# Speed: 5.3ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 12.6ms
# Speed: 2.7ms preprocess, 12.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 14.1ms
# Speed: 2.9ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 11 cows, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 16.4ms
# Speed: 3.0ms preprocess, 16.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 13.9ms
# Speed: 3.1ms preprocess, 13.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 18.1ms
# Speed: 3.2ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 15.8ms
# Speed: 3.8ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 13.3ms
# Speed: 3.4ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 20.5ms
# Speed: 4.0ms preprocess, 20.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 18.6ms
# Speed: 2.9ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 12.3ms
# Speed: 3.2ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 horse, 12 cows, 14.0ms
# Speed: 3.1ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 15.4ms
# Speed: 5.9ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 17.6ms
# Speed: 2.8ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 14.9ms
# Speed: 2.8ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 25.3ms
# Speed: 3.0ms preprocess, 25.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 14.2ms
# Speed: 3.9ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.0ms
# Speed: 3.1ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 16.0ms
# Speed: 3.5ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 17.3ms
# Speed: 4.5ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 9.2ms
# Speed: 7.1ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.1ms
# Speed: 3.1ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.2ms
# Speed: 3.1ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 12.4ms
# Speed: 2.8ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 14.6ms
# Speed: 3.4ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 9.3ms
# Speed: 3.1ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 15.2ms
# Speed: 4.1ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 16.3ms
# Speed: 2.9ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 16.2ms
# Speed: 3.4ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cows, 15.8ms
# Speed: 3.3ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 12.3ms
# Speed: 3.4ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 16.4ms
# Speed: 7.5ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 20.2ms
# Speed: 3.1ms preprocess, 20.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 12.3ms
# Speed: 2.7ms preprocess, 12.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cows, 8.9ms
# Speed: 3.0ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.5ms
# Speed: 3.6ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 15.9ms
# Speed: 2.9ms preprocess, 15.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cows, 11.9ms
# Speed: 6.2ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 13.7ms
# Speed: 2.9ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 16.5ms
# Speed: 3.9ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cows, 9.9ms
# Speed: 3.9ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 17.2ms
# Speed: 5.1ms preprocess, 17.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cows, 14.3ms
# Speed: 10.1ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 13.3ms
# Speed: 3.1ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cows, 11.9ms
# Speed: 3.2ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cows, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cows, 17.7ms
# Speed: 3.1ms preprocess, 17.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
